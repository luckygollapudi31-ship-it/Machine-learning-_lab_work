# %% [markdown]
# <a href="https://colab.research.google.com/github/luckygollapudi31-ship-it/Machine-learning-_lab_work/blob/main/Fun%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Calculator

num1 = float(input("Enter first number: "))
op = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))

if op == "+":
    print("Result:", num1 + num2)
elif op == "-":
    print("Result:", num1 - num2)
elif op == "*":
    print("Result:", num1 * num2)
elif op == "/":
    print("Result:", num1 / num2)
else:
    print("Invalid operator")
    python calculator.py
# Out:
# Enter first number: 2
# Enter operator (+, -, *, /): +
# Enter second number: 56
# Result: 58.0
